# %% [markdown]
# # Statistical process control

# %%
# Se creó una base de datos con datos aleatorios referentes al diametro en mm de pistones producidos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
df = pd.read_excel("/Users/alainzurita/Desktop/Pistones.xlsx")
df.columns
# Out:
# Index(['ID', 'Diametro_Piston '], dtype='object')

# %%
import numpy
from pyspc import *
process_control = df 
a = spc(process_control) 
print(a)
# Out:
# <pyspc: (7015577657)>

# %%
from pyspc import *
a = spc(df) + ewma()
print(a)
# Out:
# <pyspc: (-9223372029816131759)>

# %%
a + rules()
# Out:
# <pyspc: (-9223372029816131759)>

# %%
a + cusum() + xbar_sbar() + sbar()
# Out:
# <pyspc: (-9223372029816131759)>

# %%
data = df.iloc[:3] + 100
chart1 = spc(data) + xbar_rbar() + rbar() + rules()
print(chart1)
# Out:
# <pyspc: (7014943934)>
